# %% [markdown]
# # STA 561 HW2

# %% [markdown]
# ## Ruizhi Yuan (1098185, ry88), Xinyi Sheng(1207111, xs110), Luke Wang(0768279, Mlw104)

# %% [markdown]
# ## TA꞉ Jiachang Liu

# %% [markdown]
# # Problem 1

# %% [markdown]
# ## (a)

# %% [markdown]
# Closed form expression of $\mathbb{E} Z \mathbf{1}_{|Z| \leq \gamma}$ :
# $$
# \begin{aligned}
# \mathbb{E} Z \mathbf{1}_{|Z| \leq \gamma} & =\int_{-\infty}^{\infty} \frac{z}{\tau \sqrt{2 \pi}} e^{-\frac{1}{2}\left(\frac{z-\omega}{\tau}\right)^2} \mathbf{1}_{|Z| \leq \gamma} d z \\
# & =\frac{1}{\sqrt{2 \pi}} \int_{-\gamma}^\gamma \frac{z}{\tau} e^{-\frac{1}{2}\left(\frac{z-\omega}{\tau}\right)^2} d z
# \end{aligned}
# $$

# %% [markdown]
# ## (b)
# (b) Closed form expression of $\mathbb{E}\left(X-\hat{\mu}_n^H\right)^2$ :
# $$
# \begin{aligned}
# \mathbb{E}\left(X-\hat{\mu}_n^H\right)^2 & =\mathbb{E}\left((X-\mu)+\left(\mu-\hat{\mu}_n^H\right)\right)^2 \\
# & =\mathbb{E}(X-\mu)^2+\mathbb{E}\left(\mu-\hat{\mu}_n^H\right)^2 \\
# & =\sigma^2+\mathbb{E}\left(\mu-\hat{\mu}_n^H\right) \\
# & =\sigma^2+\mathbb{E}\left(\mu^2-2 \mu \hat{\mu}_n^H+\hat{\mu}_n^{H 2}\right) \\
# & =\sigma^2+\mu^2-2 \mu\left(\mathbb{E} \bar{X}_n-\mathbb{E} \bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}\right)+\mathbb{E} \hat{\mu}_n^{H 2} \\
# & =\sigma^2+\mu^2-2 \mu^2+2 \mu \mathbb{E} \bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}+\mathbb{E} \hat{\mu}_n^{H 2} \\
# & =\sigma^2-\mu^2+2 \mu \mathbb{E} \bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}+\mathbb{E} \hat{\mu}_n^H{ }^2 \\
# & =\sigma^2-\mu^2+2 \mu \mathbb{E} \bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}+\mathbb{E}\left(\bar{X}_n^2-2 \bar{X}_n\left(\bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}\right)+\left(\bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}\right)^2\right) \\
# & =\sigma^2-\mu^2+2 \mu \mathbb{E} \bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}+\mathbb{E}\left(\bar{X}_n^2\right)+\mathbb{E}\left(-2 \bar{X}_n\left(\bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}\right)+\left(\bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}\right)^2\right) \\
# & =\sigma^2-\mu^2+2 \mu \mathbb{E} \bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}+\frac{\sigma^2}{n}+\mu^2+\mathbb{E}\left(-2 \bar{X}_n\left(\bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}\right)+\left(\bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}\right)^2\right) \\
# & =\sigma^2+2 \mu \mathbb{E} \bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}+\frac{\sigma^2}{n}-\mathbb{E}\left(\bar{X}_n^2 \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}\right)
# \end{aligned}
# $$
# We can plug the closed form from (a) in for $\mathbb{E} \bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}$ and evaluate the second moment of $\bar{X}_n \mathbf{1}_{\left|\bar{X}_n\right| \leq \alpha}$ to obtain the final expression. To solve for $\alpha^{\text {opt }}$, take the derivative with respect to $\alpha$ and set the resulting expression $=0$. One can also perform a computational search across a range of $\alpha$ values to identify an approximate optimal value.

# %% [markdown]
# ## (c)
# A possible estimator of $\alpha^{\text {opt }}$ would be
# $$
# \hat{\alpha}_n=\underset{\alpha}{\arg \min }\left(\text { closed form of } \mathbb{E}\left(X-\hat{\mu}_n^H\right)^2\right)
# $$
# where $\mu$ and $\sigma^2$ are replaced with the sample mean $\left(\bar{X}=\frac{1}{n} \sum_{i=1}^n X_i\right)$ and variance, given by
# $$
# \frac{1}{n-1} \sum_{i=1}^n\left(X_i-\bar{X}\right)^2
# $$

# %% [markdown]
# # Problem 2

# %% [markdown]
# ## (a)
#
# Since $\epsilon$ and $\mathbf{X}$ are independent we see that:
# $$
# \begin{aligned}
# \operatorname{Var}(Y) & =\operatorname{Var}\left(\mathbf{X}^T \beta^*+\epsilon\right) \\
# & =\operatorname{Var}\left(\mathbf{X}^T \beta^*\right)+\operatorname{Var}(\epsilon) \\
# & =\beta^{* T} \Sigma(\rho) \beta^*+\sigma^2
# \end{aligned}
# $$

# %% [markdown]
# Also, $P\left(Y-\mathbf{X}^T \beta^*\right)^2=P \epsilon^2$ as the expected squared residuals. Since $P \epsilon=0$ then $P \epsilon^2=\sigma^2$ and $P\left(Y-\mathbf{X}^T \beta^*\right)^2=\sigma^2$.
# Thus,
# $$
# \begin{gathered}
# R^2=1-\frac{P\left(Y-\mathbf{X}^T \beta^*\right)^2}{\operatorname{Var}(Y)} \\
# =1-\frac{\sigma^2}{\beta^{* T} \Sigma(\rho) \beta^*+\sigma^2} \\
# \sigma^2=\left(\sigma^2+\beta^{* T} \Sigma(\rho) \beta^*\right)\left(1-R^2\right) \\
# \sigma^2=\left(\sigma^2\right)\left(1-R^2\right)+\left(\beta^{* T} \Sigma(\rho) \beta^*\right)\left(1-R^2\right) \\
# \sigma^2 R^2=\left(\beta^{* T} \Sigma(\rho) \beta^*\right)\left(1-R^2\right) \\
# \sigma^2=\frac{\left(\beta^{* T} \Sigma(\rho) \beta^*\right)\left(1-R^2\right)}{R^2}
# \end{gathered}
# $$
#
# Let $R^2=r$ and your final equation is:
# $$
# \sigma^2=\frac{1-r}{r}\left(\beta^{* T} \Sigma(\rho) \beta^*\right)
# $$

# %% [markdown]
# ## (b)
# When $R^2=0.8, \sigma^2$ is calculated as:
# $$
# \begin{aligned}
# 0.8 & =1-\frac{\sigma^2}{\beta^{* T} \Sigma(\rho) \beta^*+\sigma^2} \\
# 0.2 & =\frac{\sigma^2}{\beta^{* T} \Sigma(\rho) \beta^*+\sigma^2} \\
# \sigma^2 & =0.2\left(\beta^{* T} \Sigma(\rho) \beta^*+\sigma^2\right) \\
# 0.8 \sigma^2 & =0.2\left(\beta^{* T} \Sigma(\rho) \beta^*\right) \\
# \sigma^2 & =0.25\left(\beta^{* T} \Sigma(\rho) \beta^*\right)
# \end{aligned}
# $$

# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LinearRegression, LassoLarsIC, LassoLarsCV, RidgeCV, Ridge
from sklearn.metrics import mean_squared_error
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
labels = ['lasso']*3 + ['adpt_lasso']*3 + ['ridge']*3 + ['adpt_ridge']*3
Tuning_methods = ['AIC', 'BIC', 'LOO-CV']*4
labs = [labels[i] + ' ' + Tuning_methods[i] for i in range(len(labels))]
emse_table = pd.DataFrame(itertools.product(['sparse', 'dense'], labs, [10, 25, 50], [0, 0.25, 0.5]), 
                          columns = ['signal', 'methods', 'p', 'rho'])

# %%
emse_table
# Out:
#      signal            methods   p   rho
# 0    sparse          lasso AIC  10  0.00
# 1    sparse          lasso AIC  10  0.25
# 2    sparse          lasso AIC  10  0.50
# 3    sparse          lasso AIC  25  0.00
# 4    sparse          lasso AIC  25  0.25
# ..      ...                ...  ..   ...
# 211   dense  adpt_ridge LOO-CV  25  0.25
# 212   dense  adpt_ridge LOO-CV  25  0.50
# 213   dense  adpt_ridge LOO-CV  50  0.00
# 214   dense  adpt_ridge LOO-CV  50  0.25
# 215   dense  adpt_ridge LOO-CV  50  0.50
#
# [216 rows x 4 columns]

# %%
def calc_aic (y_hat, y, D, lamb):
    df_1 = np.sum(D**2/(D**2 + lamb))
    rss = np. sum((y.ravel() - y_hat.ravel())**2)
    aic = np.log(rss) + df_1*2/len(y)
    return aic

def calc_bic(y_hat, y, D, lamb):
    df_1 = np.sum(D**2/(D**2 + lamb))
    rss = np.sum((y - y_hat)**2)
    bic = np.log(rss) + df_1*np.log(len(y))/len(y)
    return bic

def lambda_ic (lambs, X, Y, X_star, Y_star, ic='aic'):
    U, D, V = np.linalg.svd(X, full_matrices=False)
    y_pred = lambda l: (U @ np.diag(D**2/(D**2 + l)) @ U.T) @ Y
    if ic=='bic':
        bic_vals = np.array([calc_bic(y_hat = y_pred(l), y=Y, D=D, lamb=l) for l in lambs])
        min_i = np.argmin(bic_vals)
    else:
        aic_vals = np.array([calc_aic(y_hat = y_pred(l), y=Y, D=D, lamb=l) for l in lambs])
        min_i = np.argmin(aic_vals)
    mse = mean_squared_error(Y, y_pred(lambs[min_i]))
    ridge = Ridge(alpha=lambs[i], fit_intercept=False)
    ridge.fit(X,Y)
    omse = mean_squared_error(Y_star, ridge.predict(X_star))
    return mse, lambs[min_i], omse

# %%
EMSES = np.zeros((24, 9))

datasets = 1000
n = 100
count = 0
test_size = 1000

# Sparse Signal
lasso_aic_mse_spr = np.zeros(9)
lasso_bic_mse_spr = np.zeros(9)
lasso_loo_mse_spr = np.zeros(9)
adp_lasso_aic_mse_spr = np.zeros(9)
adp_lasso_bic_mse_spr = np.zeros(9)
adp_lasso_loo_mse_spr = np.zeros(9)

ridge_aic_mse_spr = np.zeros(9)
ridge_bic_mse_spr = np.zeros(9)
ridge_loo_mse_spr = np.zeros(9)
adp_ridge_aic_mse_spr = np.zeros(9)
adp_ridge_bic_mse_spr = np.zeros(9)
adp_ridge_loo_mse_spr = np.zeros(9)

#Dense Signal
lasso_aic_mse_dns = np.zeros(9)
lasso_bic_mse_dns = np.zeros(9)
lasso_loo_mse_dns = np.zeros(9)
adp_lasso_aic_mse_dns = np.zeros(9)
adp_lasso_bic_mse_dns = np.zeros(9)
adp_lasso_loo_mse_dns = np.zeros(9)

ridge_aic_mse_dns = np.zeros(9)
ridge_bic_mse_dns = np.zeros(9)
ridge_loo_mse_dns = np.zeros(9)
adp_ridge_aic_mse_dns = np.zeros(9)
adp_ridge_bic_mse_dns = np.zeros(9)
adp_ridge_loo_mse_dns = np.zeros(9)

for i, (p, rho) in enumerate(itertools.product([10, 25, 50], [0, 0.25, 0.5])):
    print('p = ', p, 'rho = ', rho)
    
    # Generate data
    beta_spr = np.fromfunction(lambda j, _: (2/np.sqrt(n)) * (j + 1 <= np.sqrt(p)), (p, 1))
    beta_dns = np.fromfunction(lambda j, _: (5/((j+1) * np.sqrt(n))), (p, 1))
    Sigma_p = np.fromfunction(lambda i, j: rho**(np.abs(i -j)), (p, p))
    sigma2_spr = 0.25 * (beta_spr.T @ Sigma_p @ beta_spr)
    sigma2_dns = 0.25 * (beta_dns.T @ Sigma_p @ beta_dns)
    
    # Generate test sets
    test_epsilon_spr = np.random.normal(loc = 0, scale = np.sqrt(sigma2_spr))
    test_epsilon_dns = np.random.normal(loc = 0, scale = np.sqrt(sigma2_dns))
    
    test_X = np.random.multivariate_normal(mean = np.zeros(p), cov = Sigma_p, size = test_size)
    
    test_Y_spr = test_X @ beta_spr + test_epsilon_spr
    test_Y_dns = test_X @ beta_dns + test_epsilon_dns
    
    # LOOCV
    loo = LeaveOneOut()
    prog = tqdm(total = datasets, position = 0, leave = 2)
    for _ in range(datasets):
        count += 1
        
        epsilon_spr = np.random.normal(loc = 0, scale = np.sqrt(sigma2_spr))
        epsilon_dns = np.random.normal(loc = 0, scale = np.sqrt(sigma2_dns))
        
        X = np.random.multivariate_normal(mean = np.zeros(p), cov = Sigma_p, size = n)
        
        Y_spr = X @ beta_spr + epsilon_spr
        Y_dns = X @ beta_dns + epsilon_dns
        
        lm_spr = LinearRegression().fit(X, Y_spr)
        lm_dns = LinearRegression().fit(X, Y_dns)
        
        # Adaptive Lasso
        adX_sprL = X @ np.diagflat(np.abs(lm_spr.coef_))
        adX_dnsL = X @ np.diagflat(np.abs(lm_dns.coef_))
        
        # Adaptive Ridge
        adX_sprR = X @ np.diagflat((lm_spr.coef_**2)**(1/2))
        adX_dnsR = X @ np.diagflat((lm_dns.coef_**2)**(1/2))
        
        # Adaptive Lasso
        test_adX_sprL = test_X @ np.diagflat(np.abs(lm_spr.coef_))
        test_adX_dnsL = test_X @ np.diagflat(np.abs(lm_dns.coef_))
        
        # Adaptive Ridge
        test_adX_sprR = test_X @ np.diagflat((lm_spr.coef_**2)**(1/2))
        test_adX_dnsR = test_X @ np.diagflat((lm_dns.coef_**2)**(1/2))
        
        # Calculate lasso
        # AIC
        # Sparse
        lasso_aic_spr = LassoLarsIC(criterion='aic')
        lasso_aic_spr.fit(X, Y_spr)
        lasso_aic_mse_spr[i] += mean_squared_error(test_Y_spr, lasso_aic_spr.predict(test_X))
        
        # Dense
        lasso_aic_dns = LassoLarsIC(criterion='aic')
        lasso_aic_dns.fit(X, Y_dns)
        lasso_aic_mse_dns[i] += mean_squared_error(test_Y_dns, lasso_aic_dns.predict(test_X))
        
        # BIC
        # Sparse
        lasso_bic_spr = LassoLarsIC(criterion='bic')
        lasso_bic_spr.fit(X, Y_spr)
        lasso_bic_mse_spr[i] += mean_squared_error(test_Y_spr, lasso_bic_spr.predict(test_X))
        
        # Dense
        lasso_bic_dns = LassoLarsIC(criterion='bic')
        lasso_bic_dns.fit(X, Y_dns)
        lasso_bic_mse_dns[i] += mean_squared_error(test_Y_dns, lasso_bic_dns.predict(test_X))
        
        # LOOCV
        # Sparse
        lasso_loo_spr = LassoLarsCV(cv=loo)
        lasso_loo_spr.fit(X, Y_spr)
        lasso_loo_mse_spr[i] += mean_squared_error(test_Y_spr, lasso_loo_spr.predict(test_X))
        
        # Dense
        lasso_loo_dns = LassoLarsCV(cv=loo)
        lasso_loo_dns.fit(X, Y_dns)
        lasso_loo_mse_spr[i] += mean_squared_error(test_Y_spr, lasso_loo_spr.predict(test_X))
        
        
        # Calculate adaptive lasso
        # AIC
        # Sparse
        adp_lasso_aic_spr = LassoLarsIC(criterion='aic')
        adp_lasso_aic_spr.fit(adX_sprL, Y_spr)
        adp_lasso_aic_mse_spr[i] += mean_squared_error(test_Y_spr, adp_lasso_aic_spr.predict(test_X))
        
        # Dense
        adp_lasso_aic_dns = LassoLarsIC(criterion='aic')
        adp_lasso_aic_dns.fit(adX_dnsL, Y_dns)
        adp_lasso_aic_mse_dns[i] += mean_squared_error(test_Y_dns, adp_lasso_aic_dns.predict(test_X))
        
        # BIC
        # Sparse
        adp_lasso_bic_spr = LassoLarsIC(criterion='bic')
        adp_lasso_bic_spr.fit(adX_sprL, Y_spr)
        adp_lasso_bic_mse_spr[i] += mean_squared_error(test_Y_spr, adp_lasso_bic_spr.predict(test_X))
        
        # Dense
        adp_lasso_bic_dns = LassoLarsIC(criterion='bic')
        adp_lasso_bic_dns.fit(adX_dnsL, Y_dns)
        adp_lasso_bic_mse_dns[i] += mean_squared_error(test_Y_dns, adp_lasso_bic_dns.predict(test_X))
        
        # LOOCV
        # Sparse
        adp_lasso_loo_spr = LassoLarsCV(cv=loo)
        adp_lasso_loo_spr.fit(adX_sprL, Y_spr)
        adp_lasso_loo_mse_spr[i] += mean_squared_error(test_Y_spr, adp_lasso_loo_spr.predict(test_X))
        
        # Dense
        adp_lasso_loo_dns = LassoLarsCV(cv=loo)
        adp_lasso_loo_dns.fit(adX_dnsL, Y_dns)
        adp_lasso_loo_mse_spr[i] += mean_squared_error(test_Y_spr, adp_lasso_loo_spr.predict(test_X))
        
        # Calculat ridge
        # AIC
        lambda_rng = np.linspace(0.001, 100, num = 200)
        
        # Sparse
        _,__,mse = lambda_ic(lambda_rng, X, Y_spr, test_X, test_Y_spr, ic = 'aic')
        ridge_aic_mse_spr[i] += mse
        
        # Dense
        _,__,mse = lambda_ic(lambda_rng, X, Y_dns, test_X, test_Y_dns, ic = 'aic')
        ridge_aic_mse_dns[i] += mse
        
        # BIC
        
        # Sparse
        _,__,mse = lambda_ic(lambda_rng, X, Y_spr, test_X, test_Y_spr, ic = 'bic')
        ridge_bic_mse_spr[i] += mse
        
        # Dense
        _,__,mse = lambda_ic(lambda_rng, X, Y_dns, test_X, test_Y_dns, ic = 'bic')
        ridge_bic_mse_dns[i] += mse
        

        # LOOCV
        
        # Sparse
        ridge_loo_spr = RidgeCV(cv = loo)
        ridge_loo_spr.fit(X, Y_spr)
        ridge_loo_mse_spr[i] += mean_squared_error(test_Y_spr, ridge_loo_spr.predict(test_X))
        
        # Dense
        ridge_loo_dns = RidgeCV(cv = loo)
        ridge_loo_dns.fit(X, Y_dns)
        ridge_loo_mse_dns[i] += mean_squared_error(test_Y_dns, ridge_loo_dns.predict(test_X))
        
        
        # Calculat adaptive ridge
        # AIC

        # Sparse
        _,__,mse = lambda_ic(lambda_rng, adX_sprR, Y_spr, test_adX_sprR, test_Y_spr, ic = 'aic')
        adp_ridge_aic_mse_spr[i] += mse
        
        # Dense
        _,__,mse = lambda_ic(lambda_rng, adX_dnsR, Y_dns, test_adX_dnsR, test_Y_dns, ic = 'aic')
        adp_ridge_aic_mse_dns[i] += mse
        
        # BIC
        
        # Sparse
        _,__,mse = lambda_ic(lambda_rng, adX_sprR, Y_spr, test_adX_sprR, test_Y_spr, ic = 'bic')
        adp_ridge_bic_mse_spr[i] += mse
        
        # Dense
        _,__,mse = lambda_ic(lambda_rng, adX_dnsR, Y_dns, test_adX_dnsR, test_Y_dns, ic = 'bic')
        adp_ridge_bic_mse_dns[i] += mse
        

        # LOOCV
        
        # Sparse
        adp_ridge_loo_spr = RidgeCV(cv = loo)
        adp_ridge_loo_spr.fit(adX_sprR, Y_spr)
        adp_ridge_loo_mse_spr[i] += mean_squared_error(test_Y_spr, adp_ridge_loo_spr.predict(test_X))
        
        # Dense
        adp_ridge_loo_dns = RidgeCV(cv = loo)
        adp_ridge_loo_dns.fit(adX_dnsR, Y_dns)
        adp_ridge_loo_mse_dns[i] += mean_squared_error(test_Y_dns, adp_ridge_loo_dns.predict(test_X))
        
        prog.update()
# Out:
# p =  10 rho =  0
# 100%|███████████████████████████████████████| 1000/1000 [42:39<00:00,  1.50s/it]
# p =  10 rho =  0.25
# 100%|███████████████████████████████████████| 1000/1000 [42:39<00:00,  2.56s/it]
# 100%|███████████████████████████████████████| 1000/1000 [26:04<00:00,  1.22s/it]
# p =  10 rho =  0.5
# 100%|███████████████████████████████████████| 1000/1000 [26:04<00:00,  1.56s/it]
# 100%|███████████████████████████████████████| 1000/1000 [19:59<00:00,  1.20s/it]
# p =  25 rho =  0
# 100%|███████████████████████████████████████| 1000/1000 [19:59<00:00,  1.20s/it]
# 100%|█████████████████████████████████████| 1000/1000 [1:33:24<00:00,  1.77s/it]
# p =  25 rho =  0.25
# 100%|█████████████████████████████████████| 1000/1000 [1:33:24<00:00,  5.60s/it]
# 100%|███████████████████████████████████████| 1000/1000 [30:17<00:00,  1.83s/it]
# p =  25 rho =  0.5
# 100%|███████████████████████████████████████| 1000/1000 [30:17<00:00,  1.82s/it]
# 100%|█████████████████████████████████████| 1000/1000 [1:01:57<00:00,  1.79s/it]
# p =  50 rho =  0
# 100%|█████████████████████████████████████| 1000/1000 [1:01:57<00:00,  3.72s/it]
# 100%|███████████████████████████████████████| 1000/1000 [42:56<00:00,  2.58s/it]
# p =  50 rho =  0.25
# 100%|███████████████████████████████████████| 1000/1000 [42:56<00:00,  2.58s/it]
# 100%|█████████████████████████████████████| 1000/1000 [2:01:09<00:00,  2.57s/it]
# p =  50 rho =  0.5
# 100%|█████████████████████████████████████| 1000/1000 [2:01:09<00:00,  7.27s/it]
# 100%|█████████████████████████████████████| 1000/1000 [1:47:20<00:00,  2.46s/it]

# %%
lambda_ic(lambda_rng, X, Y_dns, test_adX_dnsR, test_Y_dns, ic = 'aic')
# Out:
# (0.26350111350686745, 0.0, 0.1517490167322219)

# %%
U, D, V = np.linalg.svd(adX_sprR, full_matrices=False)
y_pred = lambda l: (U @ np.diag(D**2/(D**2 + l)) @ U.T) @ Y_spr

aic_vals = np.array([calc_aic(y_hat = y_pred(l), y=Y_spr, D=D, lamb=l) for l in lambda_rng])
min_i = np.argmin(aic_vals)
mse = mean_squared_error(Y_spr, y_pred(lambda_rng[min_i]))
ridge = Ridge(alpha=lambda_rng[i], fit_intercept=False)
ridge.fit(X,Y_spr)
omse = mean_squared_error(Y_star, ridge.predict(X_star))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 9>()
#       7 ridge = Ridge(alpha=lambda_rng[i], fit_intercept=False)
#       8 ridge.fit(X,Y_spr)
# ----> 9 omse = mean_squared_error(Y_star, ridge.predict(X_star))
#
# NameError: name 'Y_star' is not defined

# %%
lambda_rng = np.linspace(0.001, 100, num = 200)

# %%
X
# Out:
# array([[ 1.93320569e+00, -1.75708527e+00, -4.77038145e-01,
#         -9.56921991e-01, -1.56992951e+00, -5.07672545e-01,
#          7.75335452e-02, -2.11597520e+00, -9.67435401e-01,
#         -3.48143040e-01],
#        [ 7.12430875e-01,  9.09806567e-01,  2.69135991e-01,
#          2.52896477e-01,  4.34522950e-01, -9.64175011e-01,
#         -5.21274643e-01, -2.82535948e-01,  5.84345923e-01,
#         -8.47105219e-01],
#        [-3.18378883e-01, -1.33433689e+00,  2.92021568e-02,
#         -1.03272324e+00, -9.47390411e-01,  8.96688868e-01,
#         -1.63961119e+00, -1.16707975e+00,  1.78364459e-01,
#         -1.17384289e+00],
#        [ 1.01758258e+00, -3.53916705e-01,  1.94095588e-02,
#         -1.38172205e+00,  4.48939059e-01,  6.46948541e-01,
#          9.40567938e-01,  2.31578608e-01, -6.99469858e-01,
#         -1.15831272e+00],
#        [-2.78815185e+00, -4.70978518e-01, -1.06364717e+00,
#          3.18791594e-01,  8.80571760e-01, -2.11529199e+00,
#          7.13151467e-01,  1.03523757e-01, -3.49115048e-01,
#          9.73406240e-01],
#        [ 5.86652075e-01,  4.08739255e-01, -6.21075016e-02,
#         -6.55638920e-01, -1.17396657e+00, -6.49826711e-01,
#         -7.04737045e-01,  9.45598581e-01, -1.87817693e-01,
#         -8.39222179e-01],
#        [ 1.66828791e-01,  2.01337411e-01,  6.86328683e-01,
#          1.42074662e-01,  6.34025956e-01,  9.33528692e-01,
#          1.25791989e+00, -9.02023868e-01,  1.47938103e-01,
#         -1.21587494e+00],
#        [-8.11209263e-01,  7.94983888e-01,  2.33933158e-01,
#         -4.82556466e-02,  3.79148909e-01,  3.56920412e-01,
#         -1.57392282e-04,  9.26176251e-01, -3.68494468e-02,
#         -1.35378097e+00],
#        [-8.04722412e-01, -1.43936361e+00,  2.43041946e-01,
#          4.59243575e-02, -3.88060895e-01,  2.07249705e+00,
#         -3.64710959e-02, -1.16198731e+00,  3.24240451e-01,
#         -7.90334870e-01],
#        [ 8.24220402e-01,  5.84509143e-01, -1.22865435e+00,
#         -1.89681574e+00, -1.08462188e+00, -5.19273510e-01,
#          4.30090441e-01,  1.78446023e-01,  8.56134438e-01,
#          4.05975029e-01],
#        [ 1.15245387e+00, -3.85280082e-01,  4.02453481e-01,
#          1.66855978e+00,  2.37571814e-01, -8.49290418e-01,
#         -1.08931893e-01, -1.30454121e+00, -2.99209359e-01,
#          9.20949384e-01],
#        [-2.10341569e-01, -5.95079330e-01,  3.47528203e-01,
#          1.43710780e-01,  1.54902145e+00,  1.24573829e-01,
#         -1.62254657e+00,  3.06832433e-01, -6.43342612e-01,
#         -1.25214384e+00],
#        [ 1.77158092e+00, -1.72718367e+00,  5.54069843e-01,
#         -6.61823715e-01,  8.67573579e-02,  1.52574198e+00,
#          7.50747976e-01, -2.98863327e-01,  1.52970831e+00,
#          5.95489852e-01],
#        [ 1.32577135e+00,  7.69305881e-02, -5.18351515e-01,
#         -7.81285024e-01,  3.27323256e-01, -2.61087147e+00,
#          4.69108024e-01,  5.22582464e-01,  6.64933280e-01,
#          5.50701575e-01],
#        [-4.97475041e-01, -1.64219627e+00, -2.09304339e+00,
#          1.14860082e+00,  1.46265945e+00, -1.40112198e+00,
#         -2.19797424e-01,  1.47112115e+00,  1.48085374e+00,
#         -3.48954642e-01],
#        [ 6.08624365e-02,  6.15466896e-01,  1.11824960e+00,
#          5.02289963e-01, -1.11916947e-01, -1.11755825e+00,
#         -1.12264440e-01, -6.49778546e-01,  5.63200780e-01,
#          8.97062082e-01],
#        [-6.89816186e-01, -1.07690606e+00, -1.30672333e-01,
#         -4.21522776e-01, -7.76689508e-01, -1.55066900e+00,
#          1.68392566e-01,  5.17973029e-01,  1.10017304e-01,
#         -1.32997061e+00],
#        [ 7.67174002e-02,  5.36732939e-01,  4.98594497e-01,
#          1.38928204e+00,  1.81905598e+00,  4.27751701e-01,
#         -9.46209682e-01, -9.91927575e-01, -2.18522660e+00,
#         -6.87848190e-01],
#        [-1.01595106e+00, -1.08430331e-01, -1.89003220e+00,
#          2.89517161e-01,  1.61941306e+00, -9.49172540e-01,
#          6.07504023e-02, -1.44079832e-01, -8.47019507e-01,
#         -3.17808068e-02],
#        [ 1.90155766e+00,  2.13637652e+00,  1.45940573e+00,
#          2.76476951e+00,  5.02584649e-01, -1.13346311e+00,
#          1.90133354e+00, -1.28894239e+00, -9.03284823e-01,
#          7.99605387e-02],
#        [ 1.06459639e+00, -4.47803428e-01, -2.38759979e-01,
#          8.73510973e-02, -9.16158251e-01, -1.10058003e+00,
#         -9.83699543e-01,  4.41745765e-01, -1.28466230e+00,
#         -8.76366959e-01],
#        [-1.10381216e+00, -7.03968333e-01, -7.32812800e-01,
#          1.41982366e-01, -1.06573889e-01,  3.17370110e-01,
#          4.29303031e-01, -3.00381418e-01,  3.09111905e-01,
#          9.94491028e-01],
#        [ 2.05216827e+00,  4.68104263e-02, -6.19615510e-01,
#         -5.19852154e-01,  1.77857196e+00, -1.70494178e+00,
#          3.50091324e-01,  2.13235111e+00,  4.60514741e-01,
#         -8.08784483e-01],
#        [-8.85346225e-01,  2.52749936e-01,  5.42207715e-01,
#         -4.66554744e-01,  6.95384619e-01, -7.59818327e-01,
#         -1.00157600e+00,  5.30380805e-01,  2.16612315e-02,
#          8.00835216e-01],
#        [-6.57674437e-01, -6.26426690e-01, -1.47187279e+00,
#          2.57088559e+00, -2.48159981e-01, -3.58878729e-03,
#          1.61491112e+00,  3.99787979e-01,  8.86889155e-01,
#          5.41131629e-01],
#        [-1.49377177e-01,  6.05719681e-01, -3.71680141e-02,
#         -9.46215803e-01, -3.41765695e-01,  1.88274540e+00,
#          3.13801727e-01,  8.39534882e-01, -1.01104694e+00,
#          1.47144874e+00],
#        [-8.22766763e-01, -6.27872773e-02, -8.86628583e-01,
#          1.05038912e+00,  6.60305757e-01, -1.24717605e+00,
#          3.33111377e-01,  2.25154812e+00, -5.91718262e-02,
#          4.04117486e-01],
#        [ 4.18120696e-01,  1.66078456e+00, -5.93981544e-01,
#          8.09452026e-01,  1.88412606e+00, -1.09890359e+00,
#          8.96051463e-01, -5.95218743e-01, -6.98789022e-02,
#          1.90079854e+00],
#        [-2.50010711e-02,  5.10389087e-01,  1.07007311e+00,
#          1.22538211e+00, -1.85519111e-01,  1.46755395e+00,
#         -2.44646588e-01, -5.92296362e-01,  5.92742504e-01,
#         -3.73776085e-01],
#        [-4.47028339e-01,  8.97771357e-01,  1.48237378e+00,
#          3.64450719e-01, -4.73078720e-01, -7.08691323e-01,
#          2.90450532e-01, -1.59241503e-01, -8.73757795e-01,
#         -1.93564965e+00],
#        [ 1.60373603e+00, -1.34922065e-01,  6.78610279e-01,
#         -8.61597138e-01,  3.08633444e-01,  3.12373263e-01,
#         -1.35410457e+00, -1.59484288e-01,  1.00740528e+00,
#          4.76795919e-01],
#        [-8.54114316e-01,  1.72480930e+00,  2.11707613e+00,
#          6.59289674e-01, -6.07632427e-01,  1.80336020e+00,
#         -6.42014591e-01,  7.99509354e-01, -2.70583943e-04,
#          7.12480359e-01],
#        [-4.05312250e-02,  1.66825594e-01, -1.41373898e-01,
#         -5.46932309e-01,  1.05392851e-01, -2.17624407e-01,
#          5.85132046e-01, -3.12944340e-02, -5.55072200e-01,
#         -1.38525471e+00],
#        [ 8.48297519e-01, -8.22752103e-01,  3.82227207e-01,
#         -7.22457619e-01,  9.33722208e-01,  6.51801392e-02,
#         -2.97651286e-01, -6.39954714e-02, -1.27055601e-01,
#          5.76732246e-01],
#        [ 4.33369466e-01, -8.72679656e-01,  7.10548181e-01,
#          8.71802681e-01, -8.66843587e-01,  5.28153243e-01,
#          2.75445636e-01,  1.52472913e+00, -1.32107715e+00,
#          3.67539974e-01],
#        [-2.36679838e-01,  3.60575667e-01,  4.54692448e-01,
#         -6.94267679e-01, -3.28470065e-03,  2.79436131e-01,
#         -4.60512482e-01,  5.78294265e-01, -7.11363878e-01,
#          1.50830045e+00],
#        [-6.23437813e-02,  1.97696977e-01, -2.62206670e-01,
#          2.00703964e+00,  1.51336775e+00, -1.17595525e+00,
#         -4.62514611e-02,  5.56287024e-01, -1.42163084e-01,
#         -5.17324245e-01],
#        [ 8.24559753e-01,  1.35807142e+00,  2.90489576e-01,
#         -1.64883141e+00,  2.31084409e+00,  1.75681454e+00,
#         -1.12623208e+00, -1.52187956e+00,  5.62339269e-01,
#         -1.69673966e+00],
#        [-4.24587963e-01,  1.82435090e+00,  1.12601143e+00,
#         -5.84682484e-01,  1.54672847e-01, -8.15628727e-01,
#          4.60872271e-01,  1.20011741e+00, -1.32291626e+00,
#          1.50659066e+00],
#        [-9.68405330e-01, -5.14891463e-01, -6.47316891e-01,
#         -5.89504242e-01,  1.74554140e-01, -9.09707293e-01,
#          6.29432089e-01, -7.07402459e-01,  4.56524911e-01,
#          8.02752121e-01],
#        [-4.11593474e-01, -1.82513807e+00,  1.97784454e+00,
#         -3.78861542e-01,  6.27139735e-01,  1.66023044e+00,
#         -3.26470397e-02, -4.22143864e-01,  6.57899984e-02,
#         -1.87376807e+00],
#        [-1.05449241e+00, -2.01555726e+00,  1.34501728e+00,
#          1.38735648e-01, -2.97652470e-01,  3.50163119e-01,
#          2.22844895e-01,  3.81772465e-01, -2.46825970e-01,
#         -1.86634917e+00],
#        [-1.39155427e-01,  1.16165651e-01, -7.44171913e-01,
#         -1.21171004e+00, -6.60495866e-02, -7.79126028e-01,
#          5.53815570e-01, -1.49577656e+00,  2.54677314e-01,
#          3.25887621e-01],
#        [-2.34085552e-01, -1.39639490e+00, -5.75763305e-01,
#          3.01698615e-01, -2.47909665e-01,  1.26451363e-01,
#         -3.04385640e-01,  9.30324313e-01, -2.07575767e+00,
#          5.74611736e-01],
#        [ 1.82492126e-01,  5.78861102e-01,  4.50244736e-01,
#          1.36935663e+00, -1.08406951e+00, -8.39889287e-01,
#          1.60218655e+00,  6.85393414e-01, -1.91509166e+00,
#          1.35163038e+00],
#        [-4.89312714e-03, -3.12549785e-01,  7.21384366e-01,
#         -1.27648002e+00,  9.06156837e-01,  4.72298348e-01,
#         -1.22611278e+00,  9.26475105e-01, -9.96414675e-01,
#         -1.06669952e+00],
#        [ 1.01485379e-01,  6.68324539e-02, -1.72621569e+00,
#         -6.79086521e-02, -1.29956549e-01,  1.38030954e+00,
#         -4.80662369e-01,  4.96163287e-01,  1.02347659e+00,
#          2.19945802e+00],
#        [ 6.57813502e-02,  1.00325144e+00,  8.98926297e-02,
#          9.58592647e-01,  5.52094621e-01, -6.29021909e-01,
#         -8.84245715e-01,  1.18103149e-01,  7.15158214e-01,
#         -8.11003612e-01],
#        [ 1.65433644e-01,  8.74030471e-01, -1.93719505e-01,
#         -1.54101898e+00,  2.13397340e+00, -1.77445200e+00,
#          3.79333343e-01,  7.69230046e-01, -7.47285619e-01,
#         -1.44332251e+00],
#        [-7.44060391e-01, -1.53957149e+00,  6.11276928e-01,
#         -1.75013269e-01, -2.00936669e-01,  1.38456046e+00,
#          1.00111911e+00,  1.18325187e-01,  2.90069321e-01,
#         -7.04810100e-01],
#        [ 8.69917396e-01,  3.23978463e-02,  2.16991907e-01,
#          1.61748852e+00, -4.65563613e-01,  1.02999933e+00,
#         -5.64972835e-01, -1.54913795e-01, -1.10890893e+00,
#         -2.42895322e+00],
#        [ 1.44382640e+00,  3.07879954e-01, -3.11106980e-01,
#          1.07296585e+00, -1.51756844e+00,  1.50930164e-01,
#         -6.91026277e-01,  1.04080528e+00,  2.21090297e-01,
#         -1.55007621e-01],
#        [ 1.57012367e+00,  6.77774896e-01, -2.88058082e-01,
#         -5.14957122e-01,  2.42216382e-01, -1.07972857e+00,
#          5.18639667e-01,  1.94009751e-01, -9.15772065e-01,
#         -2.72769408e-01],
#        [ 9.60263162e-01, -6.60132155e-02,  1.42829187e+00,
#         -5.92992556e-01,  6.19934350e-01, -3.19386908e-01,
#         -8.38252638e-02, -1.03720971e+00,  6.89687689e-01,
#         -7.20501430e-01],
#        [-1.08545509e-03, -2.00353740e+00, -1.93596380e+00,
#          4.68810086e-01, -5.29316895e-01,  1.54217177e+00,
#          1.97273760e-01, -6.51749302e-01,  1.44266435e+00,
#         -5.04154327e-01],
#        [-2.22507109e+00,  9.74111836e-01,  4.02075553e-01,
#         -2.52135868e-01,  8.77072103e-01,  7.59827273e-01,
#         -1.28598996e+00, -1.37891795e+00,  2.82685649e+00,
#         -2.67925864e+00],
#        [ 1.48628768e+00, -4.59678357e-01, -6.59063888e-01,
#         -5.42827859e-01,  1.29766218e+00, -1.36067705e+00,
#          1.14593177e+00, -1.28142670e+00, -1.62312412e+00,
#         -4.01069952e-01],
#        [ 1.78547611e+00,  1.00178548e+00, -1.00400033e+00,
#         -1.31613639e+00,  1.08235046e+00,  2.02056748e+00,
#         -1.14578473e-01, -8.65880728e-01, -2.74116451e+00,
#         -8.35118051e-01],
#        [-1.11361043e+00, -3.76101614e-01, -9.53712028e-01,
#         -2.13020487e-01, -4.01980747e-01, -2.20222255e-01,
#         -3.04260786e-01,  6.09147370e-01,  1.75970710e+00,
#         -2.46455269e-01],
#        [-4.23780388e-01, -5.28430523e-01,  4.26327351e-01,
#         -8.23140368e-01, -8.72633486e-01,  2.01514371e+00,
#          7.03578414e-01, -1.52226797e+00, -2.53210217e-01,
#         -2.13561623e-01],
#        [ 1.40078951e+00,  1.58518056e+00, -1.36203322e+00,
#         -7.47813615e-01,  6.65295346e-01, -5.42239113e-01,
#          8.37065199e-02, -8.00724563e-01,  2.41041837e-01,
#          7.27977474e-01],
#        [-1.07125610e-01, -1.29981253e+00, -1.50656827e+00,
#          1.38444099e+00,  7.41402646e-01, -8.26523440e-01,
#         -1.07712746e+00, -1.18443421e+00,  1.83292750e+00,
#         -3.36503622e-01],
#        [-2.38666953e+00,  2.26467111e-01, -9.77276682e-01,
#          2.89783326e-01, -1.24405571e+00, -7.13095368e-01,
#          2.19877550e+00, -7.91513181e-02, -1.28117020e+00,
#          5.17286458e-01],
#        [-1.94280383e+00,  7.55098513e-01,  2.43676038e+00,
#         -5.09275270e-01,  8.08397351e-01,  3.20193641e-01,
#          2.56311770e+00,  3.47668675e-01,  3.28842171e-01,
#          3.96382625e-01],
#        [-4.74552995e-03,  7.26574135e-01,  2.15074350e-01,
#         -1.65773781e+00,  1.32556302e+00,  1.43359023e+00,
#          2.29889663e+00,  1.06370766e+00, -1.12280962e+00,
#         -4.73037811e-01],
#        [-2.09917559e+00, -1.32041822e+00,  7.13448369e-01,
#          1.87618471e+00, -3.04140072e+00, -8.77480019e-01,
#         -9.78535897e-01, -7.12043975e-01,  2.18303950e+00,
#         -4.43460186e-01],
#        [-1.05964810e+00,  4.36111447e-01, -3.00426118e-01,
#         -4.16252451e-01,  3.18530799e-01,  8.63114588e-01,
#         -1.52676853e+00,  1.67157203e+00,  1.90013371e-01,
#          1.70004814e-01],
#        [-1.12495628e+00, -2.41597948e-01,  1.32003350e-01,
#         -1.26166683e+00,  1.30203346e+00,  7.61148892e-01,
#          3.23617656e-02, -1.18853111e+00, -3.27890582e+00,
#          1.46780474e-02],
#        [-1.77991134e+00,  7.38588820e-01,  1.03573271e-01,
#         -9.45690054e-02,  5.02693873e-01,  1.82704668e+00,
#          5.44730508e-01, -1.64720536e+00, -1.13820820e+00,
#          6.66884772e-01],
#        [ 2.02755558e+00, -4.50911397e-01,  3.12041837e-01,
#          8.79183833e-01, -5.96197142e-01, -7.61392692e-01,
#         -3.49643406e-01, -5.02790315e-01, -1.38084550e+00,
#          5.35448975e-01],
#        [-9.75477582e-01, -1.13510043e-01,  8.36500873e-01,
#         -1.93513327e+00, -1.33873366e+00, -3.17045149e+00,
#         -2.23476587e-01,  1.16931316e+00,  1.23138240e+00,
#          3.58005597e-01],
#        [-1.11128775e+00, -8.58550017e-03, -8.12177564e-01,
#         -7.39375305e-01,  2.41093900e-01,  1.80325551e+00,
#          1.60718008e+00, -6.70752857e-01,  4.95768047e-02,
#         -4.25005690e-01],
#        [ 1.12970901e+00, -5.02835273e-01,  2.12756053e-01,
#          1.75293360e+00, -7.73201544e-01, -3.82509840e-01,
#         -1.91987023e-01,  1.17304855e+00,  5.43095685e-01,
#         -1.39238867e+00],
#        [-1.37240191e-01,  1.34347261e+00,  9.72707121e-01,
#         -5.10691465e-01,  1.06387181e-01,  4.68849798e-01,
#          6.27061306e-01, -7.62552020e-01,  6.45217996e-01,
#         -4.23243205e-01],
#        [-1.03203958e+00, -2.39356241e-01,  1.19331863e+00,
#          1.30081498e+00,  4.87570155e-01, -6.88258285e-01,
#         -1.24638687e+00, -1.12857182e+00,  5.44268559e-01,
#         -6.26696283e-01],
#        [ 1.78153905e+00,  5.34725005e-01,  9.94340163e-01,
#          2.88215314e+00, -6.37359791e-01,  7.13414114e-01,
#          9.09367868e-01, -7.87249654e-01, -1.72729485e+00,
#          1.17761799e-01],
#        [ 3.34249917e-01,  7.13335029e-01,  5.13050582e-01,
#         -4.55949516e-01,  5.06651409e-02,  8.03324520e-01,
#         -1.33441009e+00,  4.61746721e-01, -8.81207809e-01,
#         -8.46013386e-01],
#        [-7.17945729e-02, -1.33359971e+00,  3.50877470e-01,
#         -8.15755242e-01, -7.65244683e-01, -2.74781153e+00,
#          1.19277661e+00, -1.85221731e-01,  1.28344164e+00,
#         -1.57528045e+00],
#        [ 1.24901501e-01,  6.09836027e-01,  1.36319962e+00,
#          3.38448336e-01,  1.85077614e+00, -5.45508987e-01,
#          5.97975569e-01, -1.80132303e-01, -9.16169850e-01,
#          3.01549389e-01],
#        [-4.78094451e-01, -1.07736095e+00,  1.75159063e+00,
#         -1.33708831e+00, -6.10323926e-01,  1.75460888e-01,
#         -2.60385303e-01, -1.35457620e-01, -5.78354350e-01,
#          1.09673019e+00],
#        [ 2.39517831e-01,  5.76687558e-02,  1.06291979e+00,
#         -1.20269429e+00,  6.89395059e-01, -3.96901479e-01,
#         -1.51147376e+00, -1.53270188e+00,  1.10350715e+00,
#         -1.39546847e+00],
#        [-1.70655944e-01, -1.37894977e+00,  3.87925511e-01,
#         -5.07662064e-01,  1.64652990e+00,  8.96455004e-01,
#          9.63149368e-02,  2.03395562e+00,  1.01379081e+00,
#          2.02171499e-01],
#        [-9.40041443e-01, -7.86202125e-01, -1.58423715e+00,
#          2.52106438e-01, -1.11613080e+00,  1.46463154e+00,
#          6.43182755e-01,  2.65961536e-01, -7.88580648e-01,
#         -1.98800790e+00],
#        [ 4.71986326e-01, -1.24360811e+00,  5.69013312e-01,
#         -1.90856573e+00, -4.03183182e-03, -3.48167792e-01,
#          5.75959720e-01,  3.48295554e-02, -1.40439681e+00,
#         -7.12893783e-01],
#        [ 4.56481610e-01,  8.57525424e-01, -1.36385570e+00,
#          1.82624825e-01,  4.37623899e-01, -8.92221574e-01,
#         -7.55564731e-01,  1.13357536e-01,  1.81725883e-01,
#          1.79805253e-01],
#        [ 6.85656196e-01, -2.90855870e-01, -8.92834701e-01,
#          1.05019269e-01, -9.12375995e-01, -1.61931464e+00,
#          1.48223291e+00, -6.23239405e-01, -5.49690235e-01,
#          1.30017657e+00],
#        [ 1.62986489e+00, -1.64209886e-01,  5.99400254e-01,
#          3.77576719e-01,  4.77179335e-01,  6.75313941e-01,
#          3.13984514e-01,  1.09768367e+00,  1.37975244e+00,
#          3.65062083e-01],
#        [-1.98401815e-01, -1.08643869e+00, -1.14248801e-01,
#          9.01440200e-02, -2.09178719e-01,  2.37696593e-01,
#         -7.20369278e-01, -1.02634650e-01, -1.28487676e+00,
#         -8.93781689e-01],
#        [-5.70978600e-01,  6.87159200e-01,  3.40390973e-01,
#          2.56728991e-01,  1.15295665e+00, -1.76021062e+00,
#         -2.09291544e+00, -2.62929255e-01,  3.79278928e-01,
#          1.38859960e-01],
#        [ 7.88201060e-01,  5.93229651e-01, -1.87165349e-01,
#          1.53866469e+00, -2.12751913e+00, -1.90765217e+00,
#          5.73120261e-01, -1.84278094e+00, -1.87895675e+00,
#          7.97456791e-01],
#        [-2.90596420e+00,  2.72906901e-01, -5.27958574e-01,
#          7.02632236e-01, -2.56574067e-01, -1.65940743e-01,
#         -3.24942227e-02, -5.57589362e-02, -7.16626841e-01,
#          2.30203300e-01],
#        [-1.79834541e+00,  6.56140345e-01, -1.30726484e-01,
#          4.22563194e-01,  1.15195220e+00, -1.08714807e+00,
#         -1.26549560e+00, -3.01171883e+00, -9.78677830e-01,
#          1.00447438e+00],
#        [-9.48898276e-01,  1.12825083e+00,  1.13710267e+00,
#          9.18677997e-01,  5.05225074e-01,  1.58374247e+00,
#          1.10991098e+00, -1.42858157e+00, -1.11794524e+00,
#          8.37214492e-01],
#        [ 2.14064298e-01, -7.84906609e-01, -9.61755225e-01,
#          3.33029884e-02, -1.05485855e+00, -1.20110730e+00,
#          9.39058723e-01,  4.53553312e-01,  3.62451522e-01,
#         -4.40103709e-01],
#        [ 8.27224745e-01, -6.01135735e-01, -3.67627813e-01,
#          5.45681505e-01, -4.66155512e-01,  1.82582118e+00,
#         -1.79345655e-01, -7.10016661e-01, -1.32990731e+00,
#          5.85785709e-01],
#        [ 1.07671848e+00,  1.85605116e+00, -5.43706488e-01,
#          3.49089201e-01, -1.50824527e+00,  3.22923530e-02,
#          2.06505308e+00, -9.01697165e-01, -3.96051254e-01,
#          1.83069558e+00],
#        [-1.16669166e+00, -4.34142113e-02,  9.89294586e-02,
#         -9.33632705e-01, -2.47035192e+00,  5.19291301e-01,
#         -8.28498729e-01, -1.40793679e+00,  2.86821311e+00,
#         -5.03881902e-02],
#        [-1.07216679e+00,  3.75841150e-01,  3.18557864e-01,
#          3.12692921e-01,  2.26429245e-01,  2.96084061e-01,
#         -4.53103695e-01, -8.02868351e-01,  1.02214172e+00,
#          1.11035531e-01],
#        [-7.01106492e-01, -2.53704514e-01,  9.76327328e-01,
#          2.59660188e+00, -9.49672881e-01, -1.88533262e+00,
#          8.21284473e-01, -1.25506262e-01,  6.49786525e-01,
#          1.26903473e+00],
#        [ 9.94509596e-01, -1.15539666e+00,  8.11124912e-03,
#         -1.25889931e+00,  3.67061525e-01, -1.26806958e+00,
#         -5.32788209e-03,  4.35540379e-01,  1.00876963e-01,
#          2.59857240e-01]])
